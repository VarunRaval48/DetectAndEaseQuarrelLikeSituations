# %%
import numpy as np
from sklearn.datasets import fetch_20newsgroups, 
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.corpus import reuters
import nltk
from gensim import models
import gensim
import lda
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Load dataset

# %% [markdown]
# ### sklearn

# %%
dataset_sklearn = fetch_20newsgroups(shuffle=True, random_state=1, remove=('headers', 'footers', 'quotes'))

# %%
len(dataset_sklearn.data)
# Out:
# 11314

# %%
tfidf_vectorizer_sklearn = TfidfVectorizer(max_df=0.95, min_df=0.01, stop_words='english')
tfidf_sklearn = tfidf_vectorizer_sklearn.fit_transform(dataset_sklearn.data)

# %%
tf_vectorizer_sklearn = CountVectorizer(max_df=0.95, min_df=0.01, stop_words='english')
tf_sklearn = tf_vectorizer_sklearn.fit_transform(dataset_sklearn.data)

# %%
word2id_sklearn = tf_vectorizer_sklearn.vocabulary_

# %%
tf_sklearn
# Out:
# <11314x1142 sparse matrix of type '<class 'numpy.int64'>'
# 	with 313237 stored elements in Compressed Sparse Row format>

# %%
id2word_sklearn = {}
for key in word2id_sklearn:
    id2word_sklearn[word2id_sklearn[key]] = key

# %% [markdown]
# ### nltk

# %%
documents = reuters.fileids()

# %%
documents
# Out:
# ['test/14826',
#  'test/14828',
#  'test/14829',
#  'test/14832',
#  'test/14833',
#  'test/14839',
#  'test/14840',
#  'test/14841',
#  'test/14842',
#  'test/14843',
#  'test/14844',
#  'test/14849',
#  'test/14852',
#  'test/14854',
#  'test/14858',
#  'test/14859',
#  'test/14860',
#  'test/14861',
#  'test/14862',
#  'test/14863',
#  'test/14865',
#  'test/14867',
#  'test/14872',
#  'test/14873',
#  'test/14875',
#  'test/14876',
#  'test/14877',
#  'test/14881',
#  'test/14882',
#  'test/14885',
#  'test/14886',
#  'test/14888',
#  'test/14890',
#  'test/14891',
#  'test/14892',
#  'test/14899',
#  'test/14900',
#  'test/14903',
#  'test/14904',
#  'test/14907',
#  'test/14909',
#  'test/14911',
#  'test/14912',
#  'test/14913',
#  'test/14918',
#  'test/14919',
#  'test/14921',
#  'test/14922',
#  'test/14923',
#  'test/14926',
#  'test/14928',
#  'test/14930',
#  'test/14931',
#  'test/14932',
#  'test/14933',
#  'test/14934',
#  'test/14941',
#  'test/14943',
#  'test/14949',
#  'test/14951',
#  'test/14954',
#  'test/14957',
#  'test/14958',
#  'test/14959',
#  'test/14960',
#  'test/14962',
#  'test/14963',
#  'test/14964',
#  'test/14965',
#  'test/14967',
#  'test/14968',
#  'test/14969',
#  'test/14970',
#  'test/14971',
#  'test/14974',
#  'test/14975',
#  'test/14978',
#  'test/14981',
#  'test/14982',
#  'test/14983',
#  'test/14984',
#  'test/14985',
#  'test/14986',
#  'test/14987',
#  'test/14988',
#  'test/14993',
#  'test/14995',
#  'test/14998',
#  'test/15000',
#  'test/15001',
#  'test/15002',
#  'test/15004',
#  'test/15005',
#  'test/15006',
#  'test/15011',
#  'test/15012',
#  'test/15013',
#  'test/15016',
#  'test/15017',
#  'test/15020',
#  'test/15023',
#  'test/15024',
#  'test/15026',
#  'test/15027',
#  'test/15028',
#  'test/15029',
#  'test/15031',
#  'test/15032',
#  'test/15033',
#  'test/15037',
#  'test/15038',
#  'test/15043',
#  'test/15045',
#  'test/15046',
#  'test/15048',
#  'test/15049',
#  'test/15052',
#  'test/15053',
#  'test/15055',
#  'test/15056',
#  'test/15060',
#  'test/15061',
#  'test/15062',
#  'test/15063',
#  'test/15065',
#  'test/15067',
#  'test/15069',
#  'test/15070',
#  'test/15074',
#  'test/15077',
#  'test/15078',
#  'test/15079',
#  'test/15082',
#  'test/15090',
#  'test/15091',
#  'test/15092',
#  'test/15093',
#  'test/15094',
#  'test/15095',
#  'test/15096',
#  'test/15097',
#  'test/15103',
#  'test/15104',
#  'test/15106',
#  'test/15107',
#  'test/15109',
#  'test/15110',
#  'test/15111',
#  'test/15112',
#  'test/15118',
#  'test/15119',
#  'test/15120',
#  'test/15121',
#  'test/15122',
#  'test/15124',
#  'test/15126',
#  'test/15128',
#  'test/15129',
#  'test/15130',
#  'test/15132',
#  'test/15136',
#  'test/15138',
#  'test/15141',
#  'test/15144',
#  'test/15145',
#  'test/15146',
#  'test/15149',
#  'test/15152',
#  'test/15153',
#  'test/15154',
#  'test/15156',
#  'test/15157',
#  'test/15161',
#  'test/15162',
#  'test/15171',
#  'test/15172',
#  'test/15175',
#  'test/15179',
#  'test/15180',
#  'test/15185',
#  'test/15188',
#  'test/15189',
#  'test/15190',
#  'test/15193',
#  'test/15194',
#  'test/15197',
#  'test/15198',
#  'test/15200',
#  'test/15204',
#  'test/15205',
#  'test/15206',
#  'test/15207',
#  'test/15208',
#  'test/15210',
#  'test/15211',
#  'test/15212',
#  'test/15213',
#  'test/15217',
#  'test/15219',
#  'test/15220',
#  'test/15221',
#  'test/15222',
#  'test/15223',
#  'test/15226',
#  'test/15227',
#  'test/15230',
#  'test/15233',
#  'test/15234',
#  'test/15237',
#  'test/15238',
#  'test/15239',
#  'test/15240',
#  'test/15242',
#  'test/15243',
#  'test/15244',
#  'test/15246',
#  'test/15247',
#  'test/15250',
#  'test/15253',
#  'test/15254',
#  'test/15255',
#  'test/15258',
#  'test/15259',
#  'test/15262',
#  'test/15263',
#  'test/15264',
#  'test/15265',
#  'test/15270',
#  'test/15271',
#  'test/15273',
#  'test/15274',
#  'test/15276',
#  'test/15278',
#  'test/15280',
#  'test/15281',
#  'test/15283',
#  'test/15287',
#  'test/15290',
#  'test/15292',
#  'test/15294',
#  'test/15295',
#  'test/15296',
#  'test/15299',
#  'test/15300',
#  'test/15302',
#  'test/15303',
#  'test/15306',
#  'test/15307',
#  'test/15308',
#  'test/15309',
#  'test/15310',
#  'test/15311',
#  'test/15312',
#  'test/15313',
#  'test/15314',
#  'test/15315',
#  'test/15321',
#  'test/15322',
#  'test/15324',
#  'test/15325',
#  'test/15326',
#  'test/15327',
#  'test/15329',
#  'test/15335',
#  'test/15336',
#  'test/15337',
#  'test/15339',
#  'test/15341',
#  'test/15344',
#  'test/15345',
#  'test/15348',
#  'test/15349',
#  'test/15351',
#  'test/15352',
#  'test/15354',
#  'test/15356',
#  'test/15357',
#  'test/15359',
#  'test/15363',
#  'test/15364',
#  'test/15365',
#  'test/15366',
#  'test/15367',
#  'test/15368',
#  'test/15372',
#  'test/15375',
#  'test/15378',
#  'test/15379',
#  'test/15380',
#  'test/15383',
#  'test/15384',
#  'test/15386',
#  'test/15387',
#  'test/15388',
#  'test/15389',
#  'test/15391',
#  'test/15394',
#  'test/15396',
#  'test/15397',
#  'test/15400',
#  'test/15404',
#  'test/15406',
#  'test/15409',
#  'test/15410',
#  'test/15411',
#  'test/15413',
#  'test/15415',
#  'test/15416',
#  'test/15417',
#  'test/15420',
#  'test/15421',
#  'test/15424',
#  'test/15425',
#  'test/15427',
#  'test/15428',
#  'test/15429',
#  'test/15430',
#  'test/15431',
#  'test/15432',
#  'test/15436',
#  'test/15438',
#  'test/15441',
#  'test/15442',
#  'test/15444',
#  'test/15446',
#  'test/15447',
#  'test/15448',
#  'test/15449',
#  'test/15450',
#  'test/15451',
#  'test/15452',
#  'test/15453',
#  'test/15454',
#  'test/15455',
#  'test/15457',
#  'test/15459',
#  'test/15460',
#  'test/15462',
#  'test/15464',
#  'test/15467',
#  'test/15468',
#  'test/15471',
#  'test/15472',
#  'test/15476',
#  'test/15477',
#  'test/15478',
#  'test/15479',
#  'test/15481',
#  'test/15482',
#  'test/15483',
#  'test/15484',
#  'test/15485',
#  'test/15487',
#  'test/15489',
#  'test/15494',
#  'test/15495',
#  'test/15496',
#  'test/15500',
#  'test/15501',
#  'test/15503',
#  'test/15504',
#  'test/15510',
#  'test/15511',
#  'test/15515',
#  'test/15520',
#  'test/15521',
#  'test/15522',
#  'test/15523',
#  'test/15527',
#  'test/15528',
#  'test/15531',
#  'test/15532',
#  'test/15535',
#  'test/15536',
#  'test/15539',
#  'test/15540',
#  'test/15542',
#  'test/15543',
#  'test/15544',
#  'test/15545',
#  'test/15547',
#  'test/15548',
#  'test/15549',
#  'test/15550',
#  'test/15551',
#  'test/15552',
#  'test/15553',
#  'test/15556',
#  'test/15558',
#  'test/15559',
#  'test/15560',
#  'test/15561',
#  'test/15562',
#  'test/15563',
#  'test/15565',
#  'test/15566',
#  'test/15567',
#  'test/15568',
#  'test/15569',
#  'test/15570',
#  'test/15571',
#  'test/15572',
#  'test/15573',
#  'test/15574',
#  'test/15575',
#  'test/15578',
#  'test/15579',
#  'test/15580',
#  'test/15581',
#  'test/15582',
#  'test/15583',
#  'test/15584',
#  'test/15585',
#  'test/15590',
#  'test/15591',
#  'test/15593',
#  'test/15594',
#  'test/15595',
#  'test/15596',
#  'test/15597',
#  'test/15598',
#  'test/15600',
#  'test/15601',
#  'test/15602',
#  'test/15603',
#  'test/15605',
#  'test/15607',
#  'test/15610',
#  'test/15613',
#  'test/15615',
#  'test/15616',
#  'test/15617',
#  'test/15618',
#  'test/15620',
#  'test/15621',
#  'test/15623',
#  'test/15624',
#  'test/15625',
#  'test/15626',
#  'test/15629',
#  'test/15632',
#  'test/15634',
#  'test/15636',
#  'test/15637',
#  'test/15639',
#  'test/15640',
#  'test/15641',
#  'test/15642',
#  'test/15643',
#  'test/15646',
#  'test/15648',
#  'test/15649',
#  'test/15651',
#  'test/15653',
#  'test/15655',
#  'test/15656',
#  'test/15664',
#  'test/15666',
#  'test/15667',
#  'test/15668',
#  'test/15669',
#  'test/15672',
#  'test/15674',
#  'test/15675',
#  'test/15676',
#  'test/15677',
#  'test/15679',
#  'test/15680',
#  'test/15682',
#  'test/15686',
#  'test/15688',
#  'test/15689',
#  'test/15691',
#  'test/15692',
#  'test/15694',
#  'test/15695',
#  'test/15696',
#  'test/15698',
#  'test/15702',
#  'test/15703',
#  'test/15704',
#  'test/15707',
#  'test/15708',
#  'test/15709',
#  'test/15710',
#  'test/15713',
#  'test/15715',
#  'test/15717',
#  'test/15719',
#  'test/15720',
#  'test/15721',
#  'test/15723',
#  'test/15725',
#  'test/15726',
#  'test/15727',
#  'test/15728',
#  'test/15729',
#  'test/15732',
#  'test/15733',
#  'test/15736',
#  'test/15737',
#  'test/15739',
#  'test/15742',
#  'test/15749',
#  'test/15751',
#  'test/15753',
#  'test/15757',
#  'test/15759',
#  'test/15762',
#  'test/15767',
#  'test/15768',
#  'test/15769',
#  'test/15772',
#  'test/15777',
#  'test/15778',
#  'test/15780',
#  'test/15782',
#  'test/15785',
#  'test/15790',
#  'test/15793',
#  'test/15797',
#  'test/15798',
#  'test/15800',
#  'test/15801',
#  'test/15803',
#  'test/15804',
#  'test/15805',
#  'test/15807',
#  'test/15808',
#  'test/15810',
#  'test/15811',
#  'test/15816',
#  'test/15817',
#  'test/15819',
#  'test/15821',
#  'test/15822',
#  'test/15823',
#  'test/15829',
#  'test/15831',
#  'test/15832',
#  'test/15833',
#  'test/15834',
#  'test/15836',
#  'test/15838',
#  'test/15840',
#  'test/15841',
#  'test/15842',
#  'test/15844',
#  'test/15845',
#  'test/15846',
#  'test/15847',
#  'test/15851',
#  'test/15852',
#  'test/15853',
#  'test/15854',
#  'test/15855',
#  'test/15856',
#  'test/15858',
#  'test/15859',
#  'test/15860',
#  'test/15861',
#  'test/15863',
#  'test/15864',
#  'test/15865',
#  'test/15866',
#  'test/15867',
#  'test/15868',
#  'test/15869',
#  'test/15870',
#  'test/15871',
#  'test/15872',
#  'test/15874',
#  'test/15875',
#  'test/15876',
#  'test/15877',
#  'test/15878',
#  'test/15879',
#  'test/15881',
#  'test/15885',
#  'test/15886',
#  'test/15888',
#  'test/15889',
#  'test/15890',
#  'test/15892',
#  'test/15893',
#  'test/15894',
#  'test/15895',
#  'test/15896',
#  'test/15897',
#  'test/15898',
#  'test/15899',
#  'test/15900',
#  'test/15901',
#  'test/15902',
#  'test/15903',
#  'test/15904',
#  'test/15906',
#  'test/15908',
#  'test/15909',
#  'test/15910',
#  'test/15911',
#  'test/15912',
#  'test/15913',
#  'test/15914',
#  'test/15916',
#  'test/15917',
#  'test/15918',
#  'test/15920',
#  'test/15921',
#  'test/15922',
#  'test/15923',
#  'test/15924',
#  'test/15925',
#  'test/15927',
#  'test/15928',
#  'test/15929',
#  'test/15930',
#  'test/15932',
#  'test/15933',
#  'test/15934',
#  'test/15937',
#  'test/15939',
#  'test/15942',
#  'test/15944',
#  'test/15949',
#  'test/15950',
#  'test/15951',
#  'test/15952',
#  'test/15953',
#  'test/15956',
#  'test/15959',
#  'test/15960',
#  'test/15961',
#  'test/15963',
#  'test/15964',
#  'test/15967',
#  'test/15968',
#  'test/15969',
#  'test/15970',
#  'test/15973',
#  'test/15975',
#  'test/15976',
#  'test/15977',
#  'test/15978',
#  'test/15979',
#  'test/15980',
#  'test/15981',
#  'test/15984',
#  'test/15985',
#  'test/15987',
#  'test/15988',
#  'test/15989',
#  'test/15993',
#  'test/15995',
#  'test/15996',
#  'test/15997',
#  'test/15999',
#  'test/16002',
#  'test/16003',
#  'test/16004',
#  'test/16005',
#  'test/16006',
#  'test/16007',
#  'test/16009',
#  'test/16012',
#  'test/16013',
#  'test/16014',
#  'test/16015',
#  'test/16016',
#  'test/16021',
#  'test/16022',
#  'test/16023',
#  'test/16026',
#  'test/16029',
#  'test/16030',
#  'test/16033',
#  'test/16037',
#  'test/16040',
#  'test/16041',
#  'test/16045',
#  'test/16052',
#  'test/16053',
#  'test/16055',
#  'test/16063',
#  'test/16066',
#  'test/16067',
#  'test/16068',
#  'test/16069',
#  'test/16071',
#  'test/16072',
#  'test/16074',
#  'test/16075',
#  'test/16076',
#  'test/16077',
#  'test/16079',
#  'test/16080',
#  'test/16083',
#  'test/16086',
#  'test/16088',
#  'test/16091',
#  'test/16093',
#  'test/16094',
#  'test/16095',
#  'test/16096',
#  'test/16097',
#  'test/16098',
#  'test/16099',
#  'test/16100',
#  'test/16103',
#  'test/16106',
#  'test/16107',
#  'test/16108',
#  'test/16110',
#  'test/16111',
#  'test/16112',
#  'test/16115',
#  'test/16117',
#  'test/16118',
#  'test/16119',
#  'test/16120',
#  'test/16122',
#  'test/16123',
#  'test/16125',
#  'test/16126',
#  'test/16130',
#  'test/16133',
#  'test/16134',
#  'test/16136',
#  'test/16139',
#  'test/16140',
#  'test/16141',
#  'test/16142',
#  'test/16143',
#  'test/16144',
#  'test/16145',
#  'test/16146',
#  'test/16147',
#  'test/16148',
#  'test/16149',
#  'test/16150',
#  'test/16152',
#  'test/16155',
#  'test/16158',
#  'test/16159',
#  'test/16161',
#  'test/16162',
#  'test/16163',
#  'test/16164',
#  'test/16166',
#  'test/16170',
#  'test/16171',
#  'test/16172',
#  'test/16173',
#  'test/16175',
#  'test/16176',
#  'test/16177',
#  'test/16179',
#  'test/16180',
#  'test/16185',
#  'test/16188',
#  'test/16189',
#  'test/16190',
#  'test/16193',
#  'test/16194',
#  'test/16195',
#  'test/16196',
#  'test/16197',
#  'test/16200',
#  'test/16201',
#  'test/16202',
#  'test/16203',
#  'test/16206',
#  'test/16207',
#  'test/16210',
#  'test/16211',
#  'test/16212',
#  'test/16213',
#  'test/16214',
#  'test/16215',
#  'test/16216',
#  'test/16219',
#  'test/16221',
#  'test/16223',
#  'test/16225',
#  'test/16226',
#  'test/16228',
#  'test/16230',
#  'test/16232',
#  'test/16233',
#  'test/16234',
#  'test/16236',
#  'test/16238',
#  'test/16241',
#  'test/16243',
#  'test/16244',
#  'test/16246',
#  'test/16247',
#  'test/16248',
#  'test/16250',
#  'test/16251',
#  'test/16252',
#  'test/16255',
#  'test/16256',
#  'test/16257',
#  'test/16258',
#  'test/16260',
#  'test/16262',
#  'test/16263',
#  'test/16264',
#  'test/16265',
#  'test/16266',
#  'test/16268',
#  'test/16269',
#  'test/16270',
#  'test/16271',
#  'test/16274',
#  'test/16275',
#  'test/16277',
#  'test/16278',
#  'test/16279',
#  'test/16281',
#  'test/16282',
#  'test/16283',
#  'test/16284',
#  'test/16285',
#  'test/16286',
#  'test/16287',
#  'test/16288',
#  'test/16289',
#  'test/16291',
#  'test/16294',
#  'test/16297',
#  'test/16298',
#  'test/16299',
#  'test/16300',
#  'test/16301',
#  'test/16302',
#  'test/16303',
#  'test/16304',
#  'test/16307',
#  'test/16310',
#  'test/16311',
#  'test/16312',
#  'test/16314',
#  'test/16315',
#  'test/16316',
#  'test/16317',
#  'test/16318',
#  'test/16319',
#  'test/16320',
#  'test/16324',
#  'test/16327',
#  'test/16331',
#  'test/16332',
#  'test/16336',
#  'test/16337',
#  'test/16339',
#  'test/16342',
#  'test/16343',
#  'test/16346',
#  'test/16347',
#  'test/16348',
#  'test/16350',
#  'test/16354',
#  'test/16357',
#  'test/16359',
#  'test/16360',
#  'test/16362',
#  'test/16363',
#  'test/16365',
#  'test/16366',
#  'test/16367',
#  'test/16369',
#  'test/16370',
#  'test/16371',
#  'test/16372',
#  'test/16374',
#  'test/16376',
#  'test/16377',
#  'test/16379',
#  'test/16380',
#  'test/16383',
#  'test/16385',
#  'test/16386',
#  'test/16388',
#  'test/16390',
#  'test/16392',
#  'test/16393',
#  'test/16394',
#  'test/16395',
#  'test/16396',
#  'test/16398',
#  'test/16399',
#  'test/16400',
#  'test/16401',
#  'test/16402',
#  'test/16403',
#  'test/16404',
#  'test/16405',
#  'test/16406',
#  'test/16407',
#  'test/16409',
#  'test/16410',
#  'test/16415',
#  'test/16417',
#  'test/16418',
#  'test/16419',
#  'test/16420',
#  'test/16421',
#  'test/16422',
#  'test/16424',
#  'test/16426',
#  'test/16427',
#  'test/16428',
#  'test/16429',
#  'test/16430',
#  'test/16432',
#  'test/16433',
#  'test/16434',
#  'test/16437',
#  'test/16438',
#  'test/16440',
#  'test/16441',
#  'test/16442',
#  'test/16443',
#  'test/16444',
#  'test/16448',
#  'test/16449',
#  'test/16450',
#  'test/16454',
#  'test/16457',
#  'test/16458',
#  'test/16459',
#  'test/16460',
#  'test/16461',
#  'test/16463',
#  'test/16465',
#  'test/16468',
#  'test/16469',
#  'test/16470',
#  'test/16471',
#  'test/16472',
#  'test/16473',
#  'test/16475',
#  'test/16476',
#  'test/16478',
#  'test/16479',
#  'test/16480',
#  'test/16481',
#  'test/16483',
#  'test/16486',
#  'test/16487',
#  'test/16488',
#  'test/16490',
#  'test/16492',
#  'test/16493',
#  'test/16495',
#  'test/16496',
#  'test/16499',
#  'test/16502',
#  'test/16505',
#  'test/16510',
#  'test/16512',
#  'test/16513',
#  'test/16518',
#  'test/16519',
#  'test/16521',
#  'test/16522',
#  'test/16523',
#  'test/16525',
#  'test/16527',
#  'test/16530',
#  'test/16531',
#  'test/16533',
#  'test/16538',
#  'test/16539',
#  'test/16545',
#  'test/16546',
#  'test/16549',
#  'test/16551',
#  'test/16554',
#  'test/16555',
#  'test/16561',
#  'test/16563',
#  'test/16564',
#  'test/16565',
#  'test/16568',
#  'test/16569',
#  'test/16570',
#  'test/16574',
#  'test/16577',
#  'test/16581',
#  'test/16583',
#  'test/16584',
#  'test/16585',
#  'test/16587',
#  'test/16588',
#  'test/16589',
#  'test/16590',
#  'test/16591',
#  ...]

# %%
reuters.open('test/14862')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-44-ec8f41660a42> in <module>()
# ----> 1 reuters.open('test/14862')
#
# /opt/anaconda3/lib/python3.5/site-packages/nltk/corpus/reader/api.py in open(self, file)
#     208         """
#     209         encoding = self.encoding(file)
# --> 210         stream = self._root.join(file).open(encoding)
#     211         return stream
#     212
#
# /opt/anaconda3/lib/python3.5/site-packages/nltk/data.py in open(self, encoding)
#     503
#     504     def open(self, encoding=None):
# --> 505         data = self._zipfile.read(self._entry)
#     506         stream = BytesIO(data)
#     507         if self._entry.endswith('.gz'):
#
# /opt/anaconda3/lib/python3.5/site-packages/nltk/data.py in read(self, name)
#     980         self.fp = open(self.filename, 'rb')
#     981         value = zipfile.ZipFile.read(self, name)
# --> 982         self.close()
#     983         return value
#     984
#
# /opt/anaconda3/lib/python3.5/zipfile.py in close(self)
#    1610             fp = self.fp
#    1611             self.fp = None
# -> 1612             self._fpclose(fp)
#    1613
#    1614     def _write_end_record(self):
#
# /opt/anaconda3/lib/python3.5/zipfile.py in _fpclose(self, fp)
#    1714
#    1715     def _fpclose(self, fp):
# -> 1716         assert self._fileRefCnt > 0
#    1717         self._fileRefCnt -= 1
#    1718         if not self._fileRefCnt and not self._filePassed:
#
# AssertionError:

# %%
reuters.words(categories=['barley', 'corn'])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-46-18d8ce3e495a> in <module>()
# ----> 1 reuters.words(categories=['barley', 'corn'])
#
# /opt/anaconda3/lib/python3.5/site-packages/nltk/corpus/reader/plaintext.py in words(self, fileids, categories)
#     161     def words(self, fileids=None, categories=None):
#     162         return PlaintextCorpusReader.words(
# --> 163             self, self._resolve(fileids, categories))
#     164     def sents(self, fileids=None, categories=None):
#     165         return PlaintextCorpusReader.sents(
#
# /opt/anaconda3/lib/python3.5/site-packages/nltk/corpus/reader/plaintext.py in _resolve(self, fileids, categories)
#     153             raise ValueError('Specify fileids or categories, not both')
#     154         if categories is not None:
# --> 155             return self.fileids(categories)
#     156         else:
#     157             return fileids
#
# /opt/anaconda3/lib/python3.5/site-packages/nltk/corpus/reader/api.py in fileids(self, categories)
#     359         else:
#     360             if self._f2c is None:
# --> 361                 self._init()
#     362             return sorted(set.union(*[self._c2f[c] for c in categories]))
#     363
#
# /opt/anaconda3/lib/python3.5/site-packages/nltk/corpus/reader/api.py in _init(self)
#     317
#     318         elif self._file is not None:
# --> 319             for line in self.open(self._file).readlines():
#     320                 line = line.strip()
#     321                 file_id, categories = line.split(self._delimiter, 1)
#
# /opt/anaconda3/lib/python3.5/site-packages/nltk/corpus/reader/api.py in open(self, file)
#     208         """
#     209         encoding = self.encoding(file)
# --> 210         stream = self._root.join(file).open(encoding)
#     211         return stream
#     212
#
# /opt/anaconda3/lib/python3.5/site-packages/nltk/data.py in open(self, encoding)
#     503
#     504     def open(self, encoding=None):
# --> 505         data = self._zipfile.read(self._entry)
#     506         stream = BytesIO(data)
#     507         if self._entry.endswith('.gz'):
#
# /opt/anaconda3/lib/python3.5/site-packages/nltk/data.py in read(self, name)
#     980         self.fp = open(self.filename, 'rb')
#     981         value = zipfile.ZipFile.read(self, name)
# --> 982         self.close()
#     983         return value
#     984
#
# /opt/anaconda3/lib/python3.5/zipfile.py in close(self)
#    1610             fp = self.fp
#    1611             self.fp = None
# -> 1612             self._fpclose(fp)
#    1613
#    1614     def _write_end_record(self):
#
# /opt/anaconda3/lib/python3.5/zipfile.py in _fpclose(self, fp)
#    1714
#    1715     def _fpclose(self, fp):
# -> 1716         assert self._fileRefCnt > 0
#    1717         self._fileRefCnt -= 1
#    1718         if not self._fileRefCnt and not self._filePassed:
#
# AssertionError:

# %%
dataset_nltk = []
for document in documents:
    dataset_nltk.append(reuters.open(document).readlines())
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-ba4fbc9f65bc> in <module>()
#       1 dataset_nltk = []
#       2 for document in documents:
# ----> 3     dataset_nltk.append(reuters.open(document).readlines())
#
# /opt/anaconda3/lib/python3.5/site-packages/nltk/corpus/reader/api.py in open(self, file)
#     208         """
#     209         encoding = self.encoding(file)
# --> 210         stream = self._root.join(file).open(encoding)
#     211         return stream
#     212
#
# /opt/anaconda3/lib/python3.5/site-packages/nltk/data.py in open(self, encoding)
#     503
#     504     def open(self, encoding=None):
# --> 505         data = self._zipfile.read(self._entry)
#     506         stream = BytesIO(data)
#     507         if self._entry.endswith('.gz'):
#
# /opt/anaconda3/lib/python3.5/site-packages/nltk/data.py in read(self, name)
#     980         self.fp = open(self.filename, 'rb')
#     981         value = zipfile.ZipFile.read(self, name)
# --> 982         self.close()
#     983         return value
#     984
#
# /opt/anaconda3/lib/python3.5/zipfile.py in close(self)
#    1610             fp = self.fp
#    1611             self.fp = None
# -> 1612             self._fpclose(fp)
#    1613
#    1614     def _write_end_record(self):
#
# /opt/anaconda3/lib/python3.5/zipfile.py in _fpclose(self, fp)
#    1714
#    1715     def _fpclose(self, fp):
# -> 1716         assert self._fileRefCnt > 0
#    1717         self._fileRefCnt -= 1
#    1718         if not self._fileRefCnt and not self._filePassed:
#
# AssertionError:

# %%
dataset_nltk_processed = []
for dataset in dataset_nltk:
    dataset_nltk_processed.append("".join(dataset))

# %%
tfidf_vectorizer_nltk = TfidfVectorizer(max_df=0.95, min_df=0.01, stop_words='english')
tf_nltk = tfidf_vectorizer_nltk.fit_transform(dataset_nltk_processed)

# %%
tf_vectorizer_nltk = CountVectorizer(max_df=0.95, min_df=0.01, stop_words='english')
tf_nltk = tf_vectorizer_nltk.fit_transform(dataset_nltk_processed)

# %%
word2id_nltk = tf_vectorizer_nltk.vocabulary_

# %%
id2word_nltk = {}
for key in word2id_nltk:
    id2word_nltk[word2id_nltk[key]] = key

# %%
id2word_nltk[900]
# Out:
# 'sources'

# %% [markdown]
# ## LDA

# %% [markdown]
# ### gensim

# %%
corpus_sklearn = gensim.matutils.Sparse2Corpus(tfidf_sklearn)

# %%
corpus_nltk = gensim.matutils.Sparse2Corpus(tf_nltk)

# %%
lda_gensim = models.ldamodel.LdaModel(corpus=corpus_sklearn, id2word=id2word_sklearn, num_topics=100)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-a1be718c94e4> in <module>()
# ----> 1 lda_gensim = models.ldamodel.LdaModel(corpus=corpus_sklearn, id2word=id2word_sklearn, num_topics=100)
#
# /opt/anaconda3/lib/python3.5/site-packages/gensim/models/ldamodel.py in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics)
#     332         if corpus is not None:
#     333             use_numpy = self.dispatcher is not None
# --> 334             self.update(corpus, chunks_as_numpy=use_numpy)
#     335
#     336     def init_dir_prior(self, prior, name):
#
# /opt/anaconda3/lib/python3.5/site-packages/gensim/models/ldamodel.py in update(self, corpus, chunksize, decay, offset, passes, update_every, eval_every, iterations, gamma_threshold, chunks_as_numpy)
#     633
#     634                 if eval_every and ((reallen == lencorpus) or ((chunk_no + 1) % (eval_every * self.numworkers) == 0)):
# --> 635                     self.log_perplexity(chunk, total_docs=lencorpus)
#     636
#     637                 if self.dispatcher:
#
# /opt/anaconda3/lib/python3.5/site-packages/gensim/models/ldamodel.py in log_perplexity(self, chunk, total_docs)
#     524         corpus_words = sum(cnt for document in chunk for _, cnt in document)
#     525         subsample_ratio = 1.0 * total_docs / len(chunk)
# --> 526         perwordbound = self.bound(chunk, subsample_ratio=subsample_ratio) / (subsample_ratio * corpus_words)
#     527         logger.info("%.3f per-word bound, %.1f perplexity estimate based on a held-out corpus of %i documents with %i words" %
#     528                     (perwordbound, np.exp2(-perwordbound), len(chunk), corpus_words))
#
# /opt/anaconda3/lib/python3.5/site-packages/gensim/models/ldamodel.py in bound(self, corpus, gamma, subsample_ratio)
#     725                 logger.debug("bound: at document #%i", d)
#     726             if gamma is None:
# --> 727                 gammad, _ = self.inference([doc])
#     728             else:
#     729                 gammad = gamma[d]
#
# /opt/anaconda3/lib/python3.5/site-packages/gensim/models/ldamodel.py in inference(self, chunk, collect_sstats)
#     435             Elogthetad = Elogtheta[d, :]
#     436             expElogthetad = expElogtheta[d, :]
# --> 437             expElogbetad = self.expElogbeta[:, ids]
#     438
#     439             # The optimal phi_{dwk} is proportional to expElogthetad_k * expElogbetad_w.
#
# IndexError: index 1339 is out of bounds for axis 1 with size 1142

# %%
lda_gensim_nltk = models.ldamodel.LdaModel(corpus=corpus_nltk, id2word=id2word_nltk, num_topics=100, update_every=1, chunksize=10000, passes=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-6d59e3cccc18> in <module>()
# ----> 1 lda_gensim_nltk = models.ldamodel.LdaModel(corpus=corpus_nltk, id2word=id2word_nltk, num_topics=100, update_every=1, chunksize=10000, passes=1)
#
# /opt/anaconda3/lib/python3.5/site-packages/gensim/models/ldamodel.py in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics)
#     332         if corpus is not None:
#     333             use_numpy = self.dispatcher is not None
# --> 334             self.update(corpus, chunks_as_numpy=use_numpy)
#     335
#     336     def init_dir_prior(self, prior, name):
#
# /opt/anaconda3/lib/python3.5/site-packages/gensim/models/ldamodel.py in update(self, corpus, chunksize, decay, offset, passes, update_every, eval_every, iterations, gamma_threshold, chunks_as_numpy)
#     633
#     634                 if eval_every and ((reallen == lencorpus) or ((chunk_no + 1) % (eval_every * self.numworkers) == 0)):
# --> 635                     self.log_perplexity(chunk, total_docs=lencorpus)
#     636
#     637                 if self.dispatcher:
#
# /opt/anaconda3/lib/python3.5/site-packages/gensim/models/ldamodel.py in log_perplexity(self, chunk, total_docs)
#     524         corpus_words = sum(cnt for document in chunk for _, cnt in document)
#     525         subsample_ratio = 1.0 * total_docs / len(chunk)
# --> 526         perwordbound = self.bound(chunk, subsample_ratio=subsample_ratio) / (subsample_ratio * corpus_words)
#     527         logger.info("%.3f per-word bound, %.1f perplexity estimate based on a held-out corpus of %i documents with %i words" %
#     528                     (perwordbound, np.exp2(-perwordbound), len(chunk), corpus_words))
#
# /opt/anaconda3/lib/python3.5/site-packages/gensim/models/ldamodel.py in bound(self, corpus, gamma, subsample_ratio)
#     725                 logger.debug("bound: at document #%i", d)
#     726             if gamma is None:
# --> 727                 gammad, _ = self.inference([doc])
#     728             else:
#     729                 gammad = gamma[d]
#
# /opt/anaconda3/lib/python3.5/site-packages/gensim/models/ldamodel.py in inference(self, chunk, collect_sstats)
#     435             Elogthetad = Elogtheta[d, :]
#     436             expElogthetad = expElogtheta[d, :]
# --> 437             expElogbetad = self.expElogbeta[:, ids]
#     438
#     439             # The optimal phi_{dwk} is proportional to expElogthetad_k * expElogbetad_w.
#
# IndexError: index 1041 is out of bounds for axis 1 with size 1017

# %%
lda_gensim_nltk.print_topics(20)
# Out:
# [(46,
#   '0.016*"comsat" + 0.014*"disdmutase" + 0.014*"dated" + 0.013*"diverting" + 0.012*"0635" + 0.011*"cabbage" + 0.010*"describes" + 0.010*"064" + 0.007*"amd" + 0.006*"edwin"'),
#  (70,
#   '0.013*"304" + 0.009*"1040" + 0.009*"bbusx" + 0.008*"calmness" + 0.008*"coop" + 0.007*"emirates" + 0.006*"estates" + 0.006*"ccimf" + 0.006*"drug" + 0.006*"contel"'),
#  (21,
#   '0.026*"acted" + 0.021*"desire" + 0.015*"bossa" + 0.014*"avaialble" + 0.013*"avaition" + 0.013*"coalition" + 0.011*"abundance" + 0.011*"acquiring" + 0.008*"admac" + 0.008*"bancorporation"'),
#  (37,
#   '0.011*"chpk" + 0.008*"amendend" + 0.008*"boycotts" + 0.008*"bedell" + 0.008*"constitutional" + 0.007*"beach" + 0.007*"beshir" + 0.007*"donated" + 0.007*"envases" + 0.006*"bulletin"'),
#  (8,
#   '0.023*"303" + 0.021*"auckland" + 0.016*"dragging" + 0.015*"appreciated" + 0.014*"167a" + 0.012*"discrepancies" + 0.012*"308" + 0.008*"coffees" + 0.008*"743" + 0.007*"entitlements"'),
#  (62,
#   '0.013*"bopa" + 0.013*"balzec" + 0.010*"101" + 0.007*"crack" + 0.007*"courier" + 0.006*"audi" + 0.004*"cramer" + 0.004*"accuracy" + 0.004*"capitalists" + 0.003*"bill"'),
#  (16,
#   '0.009*"crs" + 0.008*"awareness" + 0.007*"anwa" + 0.007*"193" + 0.006*"726" + 0.006*"contrasting" + 0.006*"323p" + 0.006*"detials" + 0.006*"623" + 0.005*"dedicate"'),
#  (81,
#   '0.016*"annoyed" + 0.012*"acts" + 0.009*"cwcc" + 0.007*"argimont" + 0.007*"earlier" + 0.006*"drive" + 0.005*"239" + 0.005*"anno" + 0.005*"cleopatra" + 0.005*"essex"'),
#  (33,
#   '0.021*"angrily" + 0.017*"altogether" + 0.016*"capitalize" + 0.015*"dds" + 0.015*"alternatives" + 0.011*"club" + 0.010*"contact" + 0.008*"909" + 0.008*"aggravating" + 0.008*"bhw"'),
#  (44,
#   '0.010*"elaboration" + 0.010*"companys" + 0.010*"complete" + 0.007*"bloch" + 0.007*"cahit" + 0.005*"colville" + 0.004*"17th" + 0.003*"chocolates" + 0.003*"computerization" + 0.003*"196"'),
#  (74,
#   '0.010*"atlantia" + 0.008*"assests" + 0.008*"cosponsor" + 0.008*"celina" + 0.008*"cme" + 0.007*"crafting" + 0.007*"armendariz" + 0.007*"christa" + 0.007*"canned" + 0.007*"chokes"'),
#  (72,
#   '0.041*"3200" + 0.037*"catalysts" + 0.029*"conserven" + 0.022*"acivities" + 0.014*"234" + 0.006*"abandoned" + 0.006*"attainable" + 0.005*"appreciated" + 0.004*"bothnia" + 0.003*"authorisation"'),
#  (49,
#   '0.019*"chcr" + 0.018*"81" + 0.008*"edgar" + 0.008*"edging" + 0.006*"centuri" + 0.005*"biogen" + 0.005*"benz" + 0.005*"bennedtt" + 0.004*"conran" + 0.003*"cng"'),
#  (36,
#   '0.013*"celeron" + 0.011*"changeover" + 0.011*"chatting" + 0.009*"1997" + 0.007*"cst" + 0.007*"1650" + 0.005*"compilers" + 0.004*"designating" + 0.004*"dilution" + 0.004*"aza"'),
#  (61,
#   '0.019*"burke" + 0.019*"albras" + 0.018*"burlilgnton" + 0.010*"aggressively" + 0.009*"037" + 0.007*"comerica" + 0.007*"appendix" + 0.006*"bpi" + 0.006*"dyr" + 0.005*"element"'),
#  (26,
#   '0.022*"clemente" + 0.020*"condemns" + 0.018*"dates" + 0.017*"dataserv" + 0.016*"chair" + 0.010*"dave" + 0.006*"division" + 0.004*"equaling" + 0.004*"domtar" + 0.003*"dosher"'),
#  (29,
#   '0.006*"1969" + 0.005*"173" + 0.005*"1904" + 0.005*"1949" + 0.005*"broadbased" + 0.005*"2002" + 0.005*"endorsing" + 0.005*"empress" + 0.005*"edmond" + 0.005*"377"'),
#  (34,
#   '0.012*"aee" + 0.009*"cuurent" + 0.008*"571" + 0.007*"automaker" + 0.006*"edson" + 0.005*"ctws" + 0.005*"blas" + 0.004*"countertrading" + 0.003*"dimensions" + 0.003*"considerations"'),
#  (0,
#   '0.010*"carolyn" + 0.009*"embodied" + 0.009*"907" + 0.008*"8900" + 0.008*"deepen" + 0.008*"chke" + 0.008*"chiles" + 0.008*"chileans" + 0.008*"djibouti" + 0.008*"bonny"'),
#  (23,
#   '0.012*"actions" + 0.010*"538" + 0.007*"cdt" + 0.006*"beaumont" + 0.006*"clarity" + 0.006*"counterbalanced" + 0.005*"abu" + 0.005*"babcock" + 0.005*"desptp" + 0.005*"deferred"')]

# %%
lda_gensim_nltk.print_topic(50)
# Out:
# '0.009*"dwg" + 0.007*"colorants" + 0.007*"ard" + 0.007*"artificially" + 0.006*"bearishness" + 0.006*"beck" + 0.006*"beet" + 0.006*"colo" + 0.006*"1315" + 0.006*"1951"'

# %% [markdown]
# ### pythonhosted lda

# %%
X = lda.datasets.load_reuters()

# %%
X_vocab = lda.datasets.load_reuters_vocab()
X_titles = lda.datasets.load_reuters_titles()

# %%
lda_python = lda.LDA(n_topics=20, n_iter=1500, random_state=1)

# %%
lda_python.fit(X)
# Out:
# INFO:lda:n_documents: 395
# INFO:lda:vocab_size: 4258
# INFO:lda:n_words: 84010
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 1500
# INFO:lda:<0> log likelihood: -1051748
# INFO:lda:<10> log likelihood: -719800
# INFO:lda:<20> log likelihood: -699115
# INFO:lda:<30> log likelihood: -689370
# INFO:lda:<40> log likelihood: -684918
# INFO:lda:<50> log likelihood: -681322
# INFO:lda:<60> log likelihood: -678979
# INFO:lda:<70> log likelihood: -676598
# INFO:lda:<80> log likelihood: -675383
# INFO:lda:<90> log likelihood: -673316
# INFO:lda:<100> log likelihood: -672761
# INFO:lda:<110> log likelihood: -671320
# INFO:lda:<120> log likelihood: -669744
# INFO:lda:<130> log likelihood: -669292
# INFO:lda:<140> log likelihood: -667940
# INFO:lda:<150> log likelihood: -668038
# INFO:lda:<160> log likelihood: -667429
# INFO:lda:<170> log likelihood: -666475
# INFO:lda:<180> log likelihood: -665562
# INFO:lda:<190> log likelihood: -664920
# INFO:lda:<200> log likelihood: -664979
# INFO:lda:<210> log likelihood: -664722
# INFO:lda:<220> log likelihood: -664459
# INFO:lda:<230> log likelihood: -664360
# INFO:lda:<240> log likelihood: -663600
# INFO:lda:<250> log likelihood: -664164
# INFO:lda:<260> log likelihood: -663826
# INFO:lda:<270> log likelihood: -663458
# INFO:lda:<280> log likelihood: -663393
# INFO:lda:<290> log likelihood: -662904
# INFO:lda:<300> log likelihood: -662294
# INFO:lda:<310> log likelihood: -662031
# INFO:lda:<320> log likelihood: -662430
# INFO:lda:<330> log likelihood: -661601
# INFO:lda:<340> log likelihood: -662108
# INFO:lda:<350> log likelihood: -662152
# INFO:lda:<360> log likelihood: -661899
# INFO:lda:<370> log likelihood: -661012
# INFO:lda:<380> log likelihood: -661278
# INFO:lda:<390> log likelihood: -661085
# INFO:lda:<400> log likelihood: -660418
# INFO:lda:<410> log likelihood: -660510
# INFO:lda:<420> log likelihood: -660343
# INFO:lda:<430> log likelihood: -659789
# INFO:lda:<440> log likelihood: -659336
# INFO:lda:<450> log likelihood: -659039
# INFO:lda:<460> log likelihood: -659329
# INFO:lda:<470> log likelihood: -658707
# INFO:lda:<480> log likelihood: -658879
# INFO:lda:<490> log likelihood: -658819
# INFO:lda:<500> log likelihood: -658407
# INFO:lda:<510> log likelihood: -658651
# INFO:lda:<520> log likelihood: -658111
# INFO:lda:<530> log likelihood: -658018
# INFO:lda:<540> log likelihood: -658111
# INFO:lda:<550> log likelihood: -657925
# INFO:lda:<560> log likelihood: -657860
# INFO:lda:<570> log likelihood: -657494
# INFO:lda:<580> log likelihood: -657723
# INFO:lda:<590> log likelihood: -657591
# INFO:lda:<600> log likelihood: -657557
# INFO:lda:<610> log likelihood: -657505
# INFO:lda:<620> log likelihood: -657730
# INFO:lda:<630> log likelihood: -657304
# INFO:lda:<640> log likelihood: -657208
# INFO:lda:<650> log likelihood: -657518
# INFO:lda:<660> log likelihood: -657541
# INFO:lda:<670> log likelihood: -657381
# INFO:lda:<680> log likelihood: -657575
# INFO:lda:<690> log likelihood: -656985
# INFO:lda:<700> log likelihood: -656815
# INFO:lda:<710> log likelihood: -656930
# INFO:lda:<720> log likelihood: -656538
# INFO:lda:<730> log likelihood: -656291
# INFO:lda:<740> log likelihood: -656417
# INFO:lda:<750> log likelihood: -656747
# INFO:lda:<760> log likelihood: -656600
# INFO:lda:<770> log likelihood: -656269
# INFO:lda:<780> log likelihood: -656311
# INFO:lda:<790> log likelihood: -656069
# INFO:lda:<800> log likelihood: -656228
# INFO:lda:<810> log likelihood: -656178
# INFO:lda:<820> log likelihood: -655694
# INFO:lda:<830> log likelihood: -655997
# INFO:lda:<840> log likelihood: -656224
# INFO:lda:<850> log likelihood: -656197
# INFO:lda:<860> log likelihood: -655889
# INFO:lda:<870> log likelihood: -656180
# INFO:lda:<880> log likelihood: -656997
# INFO:lda:<890> log likelihood: -655989
# INFO:lda:<900> log likelihood: -655615
# INFO:lda:<910> log likelihood: -655584
# INFO:lda:<920> log likelihood: -656602
# INFO:lda:<930> log likelihood: -656083
# INFO:lda:<940> log likelihood: -656294
# INFO:lda:<950> log likelihood: -656257
# INFO:lda:<960> log likelihood: -656243
# INFO:lda:<970> log likelihood: -656028
# INFO:lda:<980> log likelihood: -655603
# INFO:lda:<990> log likelihood: -656012
# INFO:lda:<1000> log likelihood: -655849
# INFO:lda:<1010> log likelihood: -655376
# INFO:lda:<1020> log likelihood: -655417
# INFO:lda:<1030> log likelihood: -655856
# INFO:lda:<1040> log likelihood: -655197
# INFO:lda:<1050> log likelihood: -655938
# INFO:lda:<1060> log likelihood: -655529
# INFO:lda:<1070> log likelihood: -655092
# INFO:lda:<1080> log likelihood: -655119
# INFO:lda:<1090> log likelihood: -656215
# INFO:lda:<1100> log likelihood: -655602
# INFO:lda:<1110> log likelihood: -655296
# INFO:lda:<1120> log likelihood: -655547
# INFO:lda:<1130> log likelihood: -655580
# INFO:lda:<1140> log likelihood: -655604
# INFO:lda:<1150> log likelihood: -655168
# INFO:lda:<1160> log likelihood: -655281
# INFO:lda:<1170> log likelihood: -655409
# INFO:lda:<1180> log likelihood: -655517
# INFO:lda:<1190> log likelihood: -654922
# INFO:lda:<1200> log likelihood: -655304
# INFO:lda:<1210> log likelihood: -655852
# INFO:lda:<1220> log likelihood: -655184
# INFO:lda:<1230> log likelihood: -655650
# INFO:lda:<1240> log likelihood: -655606
# INFO:lda:<1250> log likelihood: -656086
# INFO:lda:<1260> log likelihood: -655698
# INFO:lda:<1270> log likelihood: -655351
# INFO:lda:<1280> log likelihood: -655686
# INFO:lda:<1290> log likelihood: -654801
# INFO:lda:<1300> log likelihood: -654973
# INFO:lda:<1310> log likelihood: -655186
# INFO:lda:<1320> log likelihood: -655128
# INFO:lda:<1330> log likelihood: -655365
# INFO:lda:<1340> log likelihood: -655338
# INFO:lda:<1350> log likelihood: -655219
# INFO:lda:<1360> log likelihood: -655115
# INFO:lda:<1370> log likelihood: -654930
# INFO:lda:<1380> log likelihood: -655209
# INFO:lda:<1390> log likelihood: -654940
# INFO:lda:<1400> log likelihood: -655055
# INFO:lda:<1410> log likelihood: -655286
# INFO:lda:<1420> log likelihood: -655316
# INFO:lda:<1430> log likelihood: -655257
# INFO:lda:<1440> log likelihood: -654964
# INFO:lda:<1450> log likelihood: -654884
# INFO:lda:<1460> log likelihood: -655493
# INFO:lda:<1470> log likelihood: -655415
# INFO:lda:<1480> log likelihood: -655192
# INFO:lda:<1490> log likelihood: -655728
# INFO:lda:<1499> log likelihood: -655858

# %%
topic_word = lda_python.topic_word_

# %%
n_top_words = 8

# %%
for i, topic_dist in enumerate(topic_word):
    topic_words = np.array(X_vocab)[np.argsort(topic_dist)][:-n_top_words:-1]
    print('Topic {}: {}'.format(i, ' '.join(topic_words)))
# Out:
# Topic 0: british churchill sale million major letters west
# Topic 1: church government political country state people party
# Topic 2: elvis king fans presley life concert young
# Topic 3: yeltsin russian russia president kremlin moscow michael
# Topic 4: pope vatican paul john surgery hospital pontiff
# Topic 5: family funeral police miami versace cunanan city
# Topic 6: simpson former years court president wife south
# Topic 7: order mother successor election nuns church nirmala
# Topic 8: charles prince diana royal king queen parker
# Topic 9: film french france against bardot paris poster
# Topic 10: germany german war nazi letter christian book
# Topic 11: east peace prize award timor quebec belo
# Topic 12: n't life show told very love television
# Topic 13: years year time last church world people
# Topic 14: mother teresa heart calcutta charity nun hospital
# Topic 15: city salonika capital buddhist cultural vietnam byzantine
# Topic 16: music tour opera singer israel people film
# Topic 17: church catholic bernardin cardinal bishop wright death
# Topic 18: harriman clinton u.s ambassador paris president churchill
# Topic 19: city museum art exhibition century million churches

# %% [markdown]
# ### sklearn

# %%
lda_sklearn_sklearn = LatentDirichletAllocation(n_topics=100, doc_topic_prior=0.01, topic_word_prior=0.1)

# %%
lda_sklearn_sklearn.fit(tf_sklearn)
# Out:
# /opt/anaconda3/lib/python3.5/site-packages/sklearn/decomposition/online_lda.py:508: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=0.01,
#              evaluate_every=-1, learning_decay=0.7, learning_method=None,
#              learning_offset=10.0, max_doc_update_iter=100, max_iter=10,
#              mean_change_tol=0.001, n_jobs=1, n_topics=100, perp_tol=0.1,
#              random_state=None, topic_word_prior=0.1,
#              total_samples=1000000.0, verbose=0)

# %%
lda_sklearn_sklearn_transformed = lda_sklearn_sklearn.transform(tf_sklearn)

# %%
lda_sklearn_sklearn_transformed.shape
# Out:
# (11314, 100)

# %%
lda_sklearn_sklearn.components_.shape
# Out:
# (100, 1142)

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" %topic_idx)
        print(" ".join([feature_names[i] for i in topic.argsort()[:- n_top_words - 1:-1]]))
    print()

# %%
def print_top_topics(transformed, model, feature_names, n_top_words, n_top_topics):
    for doc_idx, doc in enumerate(transformed):
        print("Document #%d" %doc_idx)
        print(doc)
        for i in doc.argsort()[: - n_top_topics - 1 : -1]:
            topic = model.components_[i]
            print("Topic #%d:" %i)
            print(" ".join(feature_names[j] for j in topic.argsort()[: - n_top_words - 1 : -1]))
        print()

# %%
def cosine_similarity_topics(transformed):
    l = len(transformed)
    i = 0
    cosine_sim = []
    k = 0
    while i < l:
        j = i+1
        while j < l:
            cosine_sim.append(cosine_similarity(transformed[i].reshape(1, -1), transformed[j].reshape(1, -1)))
            j += 1
        i += 1

    return cosine_sim

# %%
print_top_words(lda_sklearn_sklearn, tf_vectorizer_sklearn.get_feature_names(), 20)
# Out:
# Topic #0:
# limited community provides ask killed human god trying fair sure house interface questions makes able 29 vs likely usual supported
# Topic #1:
# drive disk hard drives tape floppy cable internal supply power external mb switch access controller use 25 format new original
# Topic #2:
# evidence claim non possible argument true claims doubt clear certain natural arguments exists prove conclusion proof valid cause heard truth
# Topic #3:
# read error reading normal yes appears ed wonder save normally michael fix write rest class middle necessary return needed exact
# Topic #4:
# fbi groups individual prove month final tried problems decided wonder obvious driver likely advice chance friend applications best attempt net
# Topic #5:
# memory includes thanks sounds make sale machine interested com respond offer 16 digital know contact bike effect like try similar
# Topic #6:
# people say point think did word don agree mean just said fact different question believe saying words says make sense
# Topic #7:
# allowed reports serial references radio international season increase story points act luck experience religious safety issues date road effect gun
# Topic #8:
# use local service access product commercial users internet services national products office development provide appropriate potential building high using act
# Topic #9:
# significant basically address great ii fairly related answers hardware stated clock simply chips idea chance account slightly stay person house
# Topic #10:
# especially pass red suspect window concept money crime welcome posting door know similar 26 dave peace level command chance country
# Topic #11:
# edu graphics pub mail software available send ftp server data image com package files stuff like unix file message gov
# Topic #12:
# key chip encryption keys clipper security algorithm secret public chips phone secure technology used use communications message information data using
# Topic #13:
# bad problems run runs red baseball major shows base business deal game happen great ability times line just forget couldn
# Topic #14:
# right usa assume sold missing rule plus clearly welcome style ibm new shown entire 29 print meant let bring technical
# Topic #15:
# require lord advice command steve ms close civil ram fact middle author cars section team child player switch includes ok
# Topic #16:
# conclusion assume receive color kind summer die open play trying aren giving turn meant absolutely seen takes saying laws appreciate
# Topic #17:
# god jesus bible faith christ christians father truth son hell love lord paul man christianity way does reality john say
# Topic #18:
# israel israeli peace pay men real time government people regular small accept problem taking young really security interested price solution
# Topic #19:
# person goes talking story hot recall possibly apparently hand physical used buying place required killed longer canada currently recent reality
# Topic #20:
# level probably example comments simple uses method software using similar common easy requires write described important process allow depends large
# Topic #21:
# available systems information based data 800 includes design technical computer user include standard material including unit analysis various sources digital
# Topic #22:
# new president american press national york today washington states said united south political administration years members clinton million america groups
# Topic #23:
# mac pc serial air port ibm hp device printer print devices use mb used ms worked uses plus cheap available
# Topic #24:
# said years ago went told started took later came months home couple called got school couldn saw time weeks building
# Topic #25:
# good course bike ground advice luck piece costs expensive fun learn protection companies safety road details looking ones won unfortunately
# Topic #26:
# remember job body food supposed fair traffic shouldn avoid leave making excellent necessarily references old recent allowed condition especially just
# Topic #27:
# actually quite numbers difference check better says average early worth record straight bought completely doesn seriously absolutely used called instance
# Topic #28:
# like just thing lot really isn big ll better having things cost end good single radio little experience didn probably
# Topic #29:
# good means public government days control high systems cheap kill people away key devices right life willing law places phone
# Topic #30:
# price new want mail order selling old brand regarding everybody box net considering ones list 100 edu message send east
# Topic #31:
# think sure statement obviously lot just pretty country ways doing article saying today type totally early don designed details money
# Topic #32:
# windows dos software graphics version package ms hardware use driver run using modem pc support program application machines programs running
# Topic #33:
# reason fbi note use standard military won designed arms option section shall needed purpose add army apply intended comment general
# Topic #34:
# edu com mail cs ca send email uk sun ftp pub list request internet address ac fax contact mit available
# Topic #35:
# post list mark time days week sent letter day send directly hours perfect great future new receive decided far command
# Topic #36:
# does know like mean let maybe sounds picture cross help regards just post understand looking share apparently type based related
# Topic #37:
# sell offer sale best condition shipping asking appreciate model interested used ii respond new excellent 250 mail included hello email
# Topic #38:
# data high output input lines rate low voice handle second speed size currently wide used build function 16 uses add
# Topic #39:
# key door keys secret clipper chip doesn used use algorithm like public encryption know simply agree chips fit works possibly
# Topic #40:
# ve got just heard getting pick good like tried face noticed seeing hey come somebody maybe thought used things better
# Topic #41:
# power 000 city 100 engine 500 trade 200 miles gas house 300 options 1990 head times air 10 area 250
# Topic #42:
# need buy quality logic led willing old 30 style worth board difficult buying follows series valid cost cheap carry lower
# Topic #43:
# israel jews war israeli jewish women men killed peace land kill young blood world country killing military people human anti
# Topic #44:
# world matter free feel according way exist choice accept physical wish nature live choose opinion capable prefer fact entirely existence
# Topic #45:
# supported ac government michael price hockey book blood floppy companies doubt poor people form follows hit box interface making kept
# Topic #46:
# government law rights legal private public people court federal protect citizens society laws fact moral right policy business americans order
# Topic #47:
# cable trying intended source 93 function cards turned difficult hockey following figure problem won 25 players comp purpose references wait
# Topic #48:
# ideas personal limited suggestions thread plan standards excuse support way comment technical types today gov welcome vs poor systems lack
# Topic #49:
# means account provided increase fixed does read buying properly close act pay canada total sign clearly wide regular appear takes
# Topic #50:
# year years hit hope san road driving close pretty good quick helps expected starting paid start past couple particularly california
# Topic #51:
# car rules cars nice room hand higher lower change break regular previous bought bad pay look 90 sure 60 end
# Topic #52:
# help value using running display computer try mouse appreciated thanks set trying greatly able work working setting want application way
# Topic #53:
# 15 pretty quick inside blood head dead figure spent international areas btw totally thinking support shouldn parts scsi university clock
# Topic #54:
# people health care children family child medical drug majority group poor cause kind members born public like taken support prevent
# Topic #55:
# set control built box machine like current market area large media slow looks used manual able run equipment inside line
# Topic #56:
# scsi bus ram controller folks interface mb future fast wide hardware allows possible makes quote like just limited times currently
# Topic #57:
# team game games play season hockey players league player teams win chicago best played won goal toronto series round points
# Topic #58:
# file files program code server source directory ftp format use info faq mit pub information version section output line library
# Topic #59:
# communications edu request isn used language minutes common nearly cards quality reasonable thinking 35 copy magazine son 2nd cases instance
# Topic #60:
# os hate telling easier unix support starting meaning started cut bible party totally edu lower young member cover rest entirely
# Topic #61:
# day seen sort exactly things small btw little open really ok main inside thought student stand saw class organization like
# Topic #62:
# weeks citizens aren ideas standard quick tv 29 willing absolutely wants thousands process cases better includes hell huge law food
# Topic #63:
# use used apple unless time way light problem like good work does sure problems best tv make different easily new
# Topic #64:
# able non applications 1993 application needed 15 welcome source code new users create paper proper effort information user 24 missing
# Topic #65:
# memory speed fast program faster performance needs clock size especially happy slightly programs fully 486 ok require systems products make
# Topic #66:
# 15 wrote majority somebody prefer meant os hear included hockey interesting rule office late fair david proof created companies issues
# Topic #67:
# university research center dr page countries program points department programs form information attack international west medical public reports state scientific
# Topic #68:
# power use apple answer best able does people large win existing gives folks technology face ve solution getting really got
# Topic #69:
# image color monitor blue wife looked finally million 16 14 use size recent true model return little greater new heard
# Topic #70:
# group posting article news subject idea freedom reply posts message groups articles times steve having wanted posted mass net recently
# Topic #71:
# don know going just like ll want way say really time look doesn let water tell wouldn turn make maybe
# Topic #72:
# hear create win event events values text calls watch popular way doing really following possible action great works love yes
# Topic #73:
# space nasa earth gov station technology sci program science sign environment radio small near large office false return international designed
# Topic #74:
# problem window screen tell manager switch fine using solution changed just proper suppose way isn calling like change quickly instead
# Topic #75:
# thanks hi advance looking interested info opinions know wondering email buying appreciated knows lot getting net recently opinion general makes
# Topic #76:
# 00 question 50 answer questions cover answers ask 20 10 30 new special money magazine order free following stand return
# Topic #77:
# edu graphics pub mail ftp com send files message package server archive image gov format stuff cs file ac support
# Topic #78:
# edu graphics pub mail ftp com send image data archive computer format stuff server various files cs unix available message
# Topic #79:
# gun police guns states control weapons population crime self defense state anti laws united shot carry army safety rate likely
# Topic #80:
# stuff anybody true line deleted guess count doesn draw figure happens suspect replace ok does things times instead trying knows
# Topic #81:
# card video sound drivers board cards company 16 wait 486 installed new just does unit current know ll standard performance
# Topic #82:
# second state short coming point given street individual context instead field ready possible make action time rest place order chance
# Topic #83:
# did didn left church said man away guy time come came knew wasn night turned children saw way looked gone
# Topic #84:
# work make time real friend copy mike extra just spend cause basically way summer required lose course told mentioned friends
# Topic #85:
# lots site imagine ftp available archive looking edu army regular stand sign putting born saying immediately project contains entire great
# Topic #86:
# life christian people religion religious does believe course human follow reason good things world knowledge mind live existence john person
# Topic #87:
# book correct books original reference history particular parts understand strong lost written author version talk published modern charge wrote title
# Topic #88:
# believe case haven position works mentioned pro western language member simply authority generally belief basis speak gives issue separate meant
# Topic #89:
# bit mode pretty cd 32 80 kind worse explain way far really making common difficult cheap known necessary large don
# Topic #90:
# edu graphics mail contact pub like send effect files know bike archive server ac try com ftp cs image data
# Topic #91:
# number study cases report paper case reported compared areas used effect significant search actual size approach specific effective cause related
# Topic #92:
# black soon usually term long white practice edu interesting thinking places banks drop wants aware important good blood doing just
# Topic #93:
# thing lots understanding teams handle bought city dead totally long intended required hear available 14 difficult giving price article saw
# Topic #94:
# edu graphics pub mail send ftp com file server gov image format cs files archive stuff data ac message available
# Topic #95:
# 10 14 25 15 12 11 16 17 24 20 13 18 34 30 27 40 19 45 23 21
# Topic #96:
# wrong sorry oh newsgroup likely alt thought david yeah just don posted jim read post quote appear response excuse logic
# Topic #97:
# mr science theory discussion double scientific address force certainly stated robert continue magazine asked statement question yes certain questions include
# Topic #98:
# couple security good assume population scientific change laws false ways immediately specifically additional available electronic provided policy wants welcome references
# Topic #99:
# 1993 april 1992 93 date test apr period 10 range special 20 following final division 18 project title received 12

# %%
sen1 = ["There is a sale going on at a shop near my house", "Dan is a very good writer"]
lda_sklearn_sklearn_transformed_sen1 = lda_sklearn_sklearn.transform(tf_vectorizer_sklearn.transform(sen1))

# %%
print_top_topics(lda_sklearn_sklearn_transformed_sen1, lda_sklearn_sklearn, tf_vectorizer_sklearn.get_feature_names(), 20, 5)
# Out:
# Document #0
# [ 0.002       0.002       0.002       0.002       0.002       0.002       0.002
#   0.002       0.002       0.002       0.002       0.002       0.002       0.002
#   0.002       0.002       0.002       0.002       0.002       0.002       0.002
#   0.002       0.002       0.002       0.002       0.002       0.002       0.002
#   0.002       0.002       0.002       0.002       0.002       0.002       0.002
#   0.002       0.002       0.20200003  0.002       0.002       0.002
#   0.40200003  0.002       0.002       0.002       0.002       0.002       0.002
#   0.002       0.002       0.002       0.002       0.002       0.002       0.002
#   0.002       0.002       0.002       0.002       0.002       0.002       0.002
#   0.002       0.002       0.002       0.002       0.002       0.002       0.002
#   0.002       0.002       0.20199994  0.002       0.002       0.002       0.002
#   0.002       0.002       0.002       0.002       0.002       0.002       0.002
#   0.002       0.002       0.002       0.002       0.002       0.002       0.002
#   0.002       0.002       0.002       0.002       0.002       0.002       0.002
#   0.002       0.002       0.002     ]
# Topic #41:
# power 000 city 100 engine 500 trade 200 miles gas house 300 options 1990 head times air 10 area 250
# Topic #37:
# sell offer sale best condition shipping asking appreciate model interested used ii respond new excellent 250 mail included hello email
# Topic #71:
# don know going just like ll want way say really time look doesn let water tell wouldn turn make maybe
# Topic #99:
# 1993 april 1992 93 date test apr period 10 range special 20 following final division 18 project title received 12
# Topic #34:
# edu com mail cs ca send email uk sun ftp pub list request internet address ac fax contact mit available
#
# Document #1
# [ 0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005
#   0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005
#   0.005  0.005  0.005  0.005  0.005  0.505  0.005  0.005  0.005  0.005
#   0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005
#   0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005
#   0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005
#   0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005
#   0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005
#   0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005
#   0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005]
# Topic #25:
# good course bike ground advice luck piece costs expensive fun learn protection companies safety road details looking ones won unfortunately
# Topic #36:
# does know like mean let maybe sounds picture cross help regards just post understand looking share apparently type based related
# Topic #26:
# remember job body food supposed fair traffic shouldn avoid leave making excellent necessarily references old recent allowed condition especially just
# Topic #27:
# actually quite numbers difference check better says average early worth record straight bought completely doesn seriously absolutely used called instance
# Topic #28:
# like just thing lot really isn big ll better having things cost end good single radio little experience didn probably

# %%
cosine_similarity_topics(lda_sklearn_sklearn_transformed_sen1)
# Out:
# [array([[ 0.02395653]])]
